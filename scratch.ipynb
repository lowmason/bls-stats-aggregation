# %%
from bls_stats import download_qcew_bulk, map_bulk_to_ces

# %%
bulk_path = download_qcew_bulk(start_year=2024, end_year=2024)
# Out:
#   downloading 2024 quarterly singlefile ...
#     2024: kept 49,948 rows (291 MB downloaded)
#   wrote data/qcew_bulk.parquet (49,948 rows)

# %%
ces = map_bulk_to_ces(bulk_path)
# Out:
#   bulk: 24,060 rows across 37 industries

# %%
print('Industry codes:', ces['industry_code'].unique().sort().to_list())
print()
nat = ces.filter(ces['geographic_type'] == 'national').sort('industry_code')
for row in nat.unique(subset=['industry_code', 'industry_type']).sort('industry_code').iter_rows(named=True):
    print(f"  {row['industry_code']:>3s}  {row['industry_type']}")
# Out:
# Industry codes: ['00', '05', '06', '07', '08', '10', '20', '21', '22', '23', '30', '31', '32', '40', '42', '44', '48', '50', '51', '52', '53', '54', '55', '56', '60', '61', '62', '65', '70', '71', '72', '80', '81', '90', '91', '92', '93']
#
#    00  national
#    05  domain
#    06  domain
#    07  domain
#    08  domain
#    10  supersector
#    20  supersector
#    21  sector
#    22  sector
#    23  sector
#    30  supersector
#    31  sector
#    32  sector
#    40  supersector
#    42  sector
#    44  sector
#    48  sector
#    50  supersector
#    51  sector
#    52  sector
#    53  sector
#    54  sector
#    55  supersector
#    55  sector
#    56  sector
#    60  supersector
#    61  sector
#    62  sector
#    65  supersector
#    70  supersector
#    71  sector
#    72  sector
#    80  supersector
#    81  sector
#    90  supersector
#    91  sector
#    92  sector
#    93  sector

# %%
ces
# Out:
# shape: (24_060, 6)
# ┌─────────────────┬─────────────────┬───────────────┬───────────────┬────────────┬────────────┐
# │ geographic_type ┆ geographic_code ┆ industry_type ┆ industry_code ┆ ref_date   ┆ employment │
# │ ---             ┆ ---             ┆ ---           ┆ ---           ┆ ---        ┆ ---        │
# │ str             ┆ str             ┆ str           ┆ str           ┆ date       ┆ f64        │
# ╞═════════════════╪═════════════════╪═══════════════╪═══════════════╪════════════╪════════════╡
# │ state           ┆ 01              ┆ national      ┆ 00            ┆ 2024-01-12 ┆ 2070.184   │
# │ state           ┆ 01              ┆ national      ┆ 00            ┆ 2024-04-12 ┆ 2103.439   │
# │ state           ┆ 01              ┆ national      ┆ 00            ┆ 2024-07-12 ┆ 2100.483   │
# │ state           ┆ 01              ┆ national      ┆ 00            ┆ 2024-10-12 ┆ 2117.906   │
# │ state           ┆ 02              ┆ national      ┆ 00            ┆ 2024-01-12 ┆ 309.376    │
# │ …               ┆ …               ┆ …             ┆ …             ┆ …          ┆ …          │
# │ state           ┆ 55              ┆ domain        ┆ 08            ┆ 2024-12-12 ┆ 1922.981   │
# │ state           ┆ 48              ┆ domain        ┆ 08            ┆ 2024-01-12 ┆ 9631.446   │
# │ state           ┆ 27              ┆ domain        ┆ 08            ┆ 2024-05-12 ┆ 2067.409   │
# │ state           ┆ 26              ┆ domain        ┆ 08            ┆ 2024-08-12 ┆ 3004.244   │
# │ state           ┆ 56              ┆ domain        ┆ 08            ┆ 2024-01-12 ┆ 152.541    │
# └─────────────────┴─────────────────┴───────────────┴───────────────┴────────────┴────────────┘
